# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Python Official Docs](https://docs.python.org/3/) — Language reference
# - [Real Python](https://realpython.com/) — Practical tutorials
# - [Python Design Patterns](https://python-patterns.guide/) — Advanced patterns
# - [Fluent Python (book)](https://www.oreilly.com/library/view/fluent-python-2nd/9781492056348/) — Advanced Python
