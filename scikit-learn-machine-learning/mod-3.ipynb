# %% [markdown]
# # Scikit Learn Machine Learning - mod-3
#
# **Course:** scikit-learn-machine-learning
#
# Run the code cells below to practice. Code is loaded from GitHub using IPython magic.

# %%
# %load https://raw.githubusercontent.com/ailearningclub/ailearningclub-collab/main/code/scikit-learn-machine-learning/mod-3/part-1.py
