# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [AWS Bedrock Documentation](https://docs.aws.amazon.com/bedrock/) — Official docs
# - [Bedrock User Guide](https://docs.aws.amazon.com/bedrock/latest/userguide/) — Detailed guides
# - [AWS Bedrock Pricing](https://aws.amazon.com/bedrock/pricing/) — Cost reference
# - [LangChain Bedrock](https://python.langchain.com/docs/integrations/llms/bedrock/) — LangChain integration
# - [Anthropic Claude Docs](https://docs.anthropic.com/) — Claude model documentation
# - [AWS Samples (GitHub)](https://github.com/aws-samples/amazon-bedrock-samples) — Code examples
