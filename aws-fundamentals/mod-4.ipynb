# %% [markdown]
# # S3 & Storage

# %% [markdown]
# ## S3 Buckets and Objects

# %% [markdown]
# An **S3 bucket** is a container for objects. Bucket names must be globally unique across all AWS accounts. Objects are files stored in buckets, identified by a key (path).
#
# S3 provides 99.999999999% (11 nines) durability and 99.99% availability. Data is automatically replicated across multiple availability zones.

# %% [markdown]
# ## Storage Classes

# %% [markdown]
# S3 offers different storage classes for different access patterns and cost optimization:
#
# **S3 Standard** is for frequently accessed data. Highest cost per GB but no retrieval fees.
#
# **S3 Intelligent-Tiering** automatically moves objects between access tiers based on usage patterns.
#
# **S3 Standard-IA** (Infrequent Access) is cheaper but has retrieval fees. Use for data accessed less than once per month.
#
# **S3 Glacier** is for long-term archival. Very cheap but retrieval takes hours.
#
# **S3 Glacier Deep Archive** is the cheapest option for data rarely accessed.

# %% [markdown]
# ## Versioning and Lifecycle Policies

# %% [markdown]
# **Versioning** keeps multiple versions of objects. When you upload a new version, the old version is retained. This protects against accidental deletion and allows rollback.
#
# **Lifecycle policies** automatically transition objects between storage classes or delete them based on age. For example, move objects to Glacier after 90 days.

# %% [markdown]
# ## Hands-On: Create and Manage S3 Bucket

# %% [markdown]
# Create a bucket:
#
# ```bash
# aws s3 mb s3://my-unique-bucket-name
# ```
#
# Upload a file:
#
# ```bash
# aws s3 cp myfile.txt s3://my-unique-bucket-name/
# ```
#
# List bucket contents:
#
# ```bash
# aws s3 ls s3://my-unique-bucket-name/
# ```
#
# Enable versioning:
#
# ```bash
# aws s3api put-bucket-versioning --bucket my-unique-bucket-name \
#   --versioning-configuration Status=Enabled
# ```
#
# Create a lifecycle policy:
#
# ```bash
# aws s3api put-bucket-lifecycle-configuration --bucket my-unique-bucket-name \
#   --lifecycle-configuration '{
#     "Rules": [
#       {
#         "Id": "archive-rule",
#         "Status": "Enabled",
#         "Transitions": [
#           {
#             "Days": 90,
#             "StorageClass": "GLACIER"
#           }
#         ]
#       }
#     ]
#   }'
# ```

# %% [markdown]
# ## Python Boto3 Example

# %%
import boto3

s3 = boto3.client('s3')

# Create bucket
s3.create_bucket(Bucket='my-unique-bucket-name')

# Upload file
s3.upload_file('myfile.txt', 'my-unique-bucket-name', 'myfile.txt')

# List objects
response = s3.list_objects_v2(Bucket='my-unique-bucket-name')
for obj in response.get('Contents', []):
    print(f"Key: {obj['Key']}, Size: {obj['Size']}")

# Download file
s3.download_file('my-unique-bucket-name', 'myfile.txt', 'downloaded.txt')

# Delete object
s3.delete_object(Bucket='my-unique-bucket-name', Key='myfile.txt')

# %% [markdown]
# ## Terraform Example

# %% [markdown]
# ```hcl
# resource "aws_s3_bucket" "data" {
#   bucket = "my-unique-bucket-name"
# }
#
# resource "aws_s3_bucket_versioning" "data" {
#   bucket = aws_s3_bucket.data.id
#
#   versioning_configuration {
#     status = "Enabled"
#   }
# }
#
# resource "aws_s3_bucket_lifecycle_configuration" "data" {
#   bucket = aws_s3_bucket.data.id
#
#   rule {
#     id     = "archive-rule"
#     status = "Enabled"
#
#     transition {
#       days          = 90
#       storage_class = "GLACIER"
#     }
#   }
# }
#
# resource "aws_s3_object" "file" {
#   bucket = aws_s3_bucket.data.id
#   key    = "myfile.txt"
#   source = "myfile.txt"
# }
# ```

# %% [markdown]
# ## S3 Access Control

# %% [markdown]
# S3 buckets are private by default. Use bucket policies to grant access:
#
# ```json
# {
#   "Version": "2012-10-17",
#   "Statement": [
#     {
#       "Effect": "Allow",
#       "Principal": "*",
#       "Action": "s3:GetObject",
#       "Resource": "arn:aws:s3:::my-unique-bucket-name/*"
#     }
#   ]
# }
# ```

# %% [markdown]
# ## Quiz 1

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What is an S3 bucket?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="0">
#       <span>A container for objects in S3</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="1">
#       <span>A virtual machine</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="2">
#       <span>A database table</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="3">
#       <span>A network interface</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2

# %% [markdown]
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ Which S3 storage class is best for long-term archival?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8293847" value="0">
#       <span>S3 Standard</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8293847" value="1">
#       <span>S3 Standard-IA</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8293847" value="2">
#       <span>S3 Glacier</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8293847" value="3">
#       <span>S3 Intelligent-Tiering</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What does S3 versioning do?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5738291" value="0">
#       <span>Encrypts objects</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5738291" value="1">
#       <span>Keeps multiple versions of objects for rollback</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5738291" value="2">
#       <span>Compresses objects</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5738291" value="3">
#       <span>Replicates objects across regions</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What is an S3 lifecycle policy?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9384756" value="0">
#       <span>Automatically transitions objects between storage classes or deletes them</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9384756" value="1">
#       <span>Encrypts objects at rest</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9384756" value="2">
#       <span>Grants user access to buckets</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9384756" value="3">
#       <span>Monitors bucket activity</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is the default access level for a new S3 bucket?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="0">
#       <span>Public</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="1">
#       <span>Private</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="2">
#       <span>Read-only</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="3">
#       <span>Depends on region</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
