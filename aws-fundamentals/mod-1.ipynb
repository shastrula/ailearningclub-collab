# %% [markdown]
# # Introduction to Cloud & AWS

# %% [markdown]
# ## Cloud Computing Models

# %% [markdown]
# Cloud computing offers three primary service models:
#
# **Infrastructure as a Service (IaaS)** provides virtualized computing resources over the internet. You manage applications, data, and runtime; AWS manages infrastructure, storage, and networking. EC2 is AWS's primary IaaS offering.
#
# **Platform as a Service (PaaS)** abstracts infrastructure management. You focus on code; AWS handles servers, databases, and scaling. Elastic Beanstalk and App Runner are PaaS services.
#
# **Software as a Service (SaaS)** delivers fully managed applications. Users access via browser; AWS manages everything. Salesforce and Microsoft 365 are examples.

# %% [markdown]
# ## AWS Regions and Availability Zones

# %% [markdown]
# AWS infrastructure is organized hierarchically. A **Region** is a geographic area containing multiple isolated data centers. Each region has at least 3 **Availability Zones (AZs)** — physically separate data centers with independent power, cooling, and networking.
#
# This architecture provides high availability and disaster recovery. If one AZ fails, applications in other AZs continue running. Regions are isolated for compliance and latency optimization.

# %% [markdown]
# ## Global Infrastructure

# %% [markdown]
# Beyond regions and AZs, AWS operates **Edge Locations** for content delivery via CloudFront CDN, and **Local Zones** for ultra-low latency applications near major cities.

# %% [markdown]
# ## Hands-On: Explore AWS Regions

# %% [markdown]
# List all available regions:
#
# ```bash
# aws ec2 describe-regions --query 'Regions[*].[RegionName,Endpoint]' --output table
# ```
#
# Get availability zones in your default region:
#
# ```bash
# aws ec2 describe-availability-zones --query 'AvailabilityZones[*].[ZoneName,State]' --output table
# ```
#
# Check your current AWS account and region:
#
# ```bash
# aws sts get-caller-identity
# aws configure get region
# ```
#
# Set default region for CLI:
#
# ```bash
# export AWS_DEFAULT_REGION=us-east-1
# aws configure set region us-west-2
# ```
#
# Verify region configuration:
#
# ```bash
# aws ec2 describe-regions --region-names us-east-1 us-west-2 --output json
# ```

# %% [markdown]
# ## AWS Global Services

# %% [markdown]
# Some AWS services are global and don't require region selection: IAM, CloudFront, Route 53, and AWS Organizations. Most services are region-specific.

# %% [markdown]
# ## Quiz 1

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ Which cloud model provides the most control over infrastructure?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7284931" value="0">
#       <span>SaaS</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7284931" value="1">
#       <span>IaaS</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7284931" value="2">
#       <span>PaaS</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7284931" value="3">
#       <span>All provide equal control</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2

# %% [markdown]
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ What is the primary purpose of Availability Zones?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5821047" value="0">
#       <span>To reduce AWS costs</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5821047" value="1">
#       <span>To provide faster internet speeds</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5821047" value="2">
#       <span>To provide high availability and fault tolerance</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5821047" value="3">
#       <span>To store backup data</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ Which AWS service is global and does NOT require region selection?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9384756" value="0">
#       <span>IAM</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9384756" value="1">
#       <span>EC2</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9384756" value="2">
#       <span>RDS</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9384756" value="3">
#       <span>S3</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4

# %% [markdown]
# <div class="quiz" data-correct="3">
#   <p class="font-semibold mb-3">❓ How many Availability Zones does each AWS Region have at minimum?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="0">
#       <span>1</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="1">
#       <span>2</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="2">
#       <span>4</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="3">
#       <span>3</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is CloudFront in AWS?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="0">
#       <span>A database service</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="1">
#       <span>A content delivery network (CDN)</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="2">
#       <span>A compute service</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="3">
#       <span>A networking firewall</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
