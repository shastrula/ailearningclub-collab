# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [SageMaker Documentation](https://docs.aws.amazon.com/sagemaker/) — Official docs
# - [SageMaker Python SDK](https://sagemaker.readthedocs.io/) — SDK reference
# - [SageMaker Examples (GitHub)](https://github.com/aws/amazon-sagemaker-examples) — Code samples
# - [AWS ML Blog](https://aws.amazon.com/blogs/machine-learning/) — Latest ML posts
# - [SageMaker Pricing](https://aws.amazon.com/sagemaker/pricing/) — Cost reference
# - [AWS ML Certification](https://aws.amazon.com/certification/certified-machine-learning-specialty/) — ML specialty cert
