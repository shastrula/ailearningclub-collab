# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Prophet Documentation](https://facebook.github.io/prophet/) — Facebook's forecasting tool
# - [statsmodels](https://www.statsmodels.org/) — Statistical models (ARIMA, SARIMA)
# - [Darts](https://unit8co.github.io/darts/) — Time series library
# - [Nixtla](https://nixtla.io/) — Time series forecasting tools
