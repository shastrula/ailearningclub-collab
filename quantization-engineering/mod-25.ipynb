# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Hugging Face Quantization](https://huggingface.co/docs/transformers/quantization) — Quantization guide
# - [GPTQ Paper](https://arxiv.org/abs/2210.17323) — Post-training quantization
# - [AWQ Paper](https://arxiv.org/abs/2306.00978) — Activation-aware quantization
# - [llama.cpp](https://github.com/ggerganov/llama.cpp) — GGUF quantization
