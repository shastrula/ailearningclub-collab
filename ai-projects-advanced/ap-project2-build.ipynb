# %% [markdown]
# # Ai Projects Advanced - ap-project2-build
#
# **Course:** ai-projects-advanced
#
# Run the code cells below to practice. Code is loaded from GitHub using IPython magic.

# %%
# %load https://raw.githubusercontent.com/ailearningclub/ailearningclub-collab/main/code/ai-projects-advanced/ap-project2-build/part-1.py
