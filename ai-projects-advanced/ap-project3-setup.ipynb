# %% [markdown]
# # Ai Projects Advanced - ap-project3-setup
#
# **Course:** ai-projects-advanced
#
# Run the code cells below to practice. Code is loaded from GitHub using IPython magic.

# %%
# %load https://raw.githubusercontent.com/ailearningclub/ailearningclub-collab/main/code/ai-projects-advanced/ap-project3-setup/part-1.py
