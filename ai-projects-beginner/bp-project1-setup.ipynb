# %% [markdown]
# # Ai Projects Beginner - bp-project1-setup
#
# **Course:** ai-projects-beginner
#
# Run the code cells below to practice. Code is loaded from GitHub using IPython magic.

# %%
# %load https://raw.githubusercontent.com/ailearningclub/ailearningclub-collab/main/code/ai-projects-beginner/bp-project1-setup/part-1.py
