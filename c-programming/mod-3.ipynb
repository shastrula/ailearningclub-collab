# %% [markdown]
# # Operators & Expressions

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int a = 10, b = 3;
#
#     printf("Addition: %d + %d = %d\n", a, b, a + b);      // 13
#     printf("Subtraction: %d - %d = %d\n", a, b, a - b);   // 7
#     printf("Multiplication: %d * %d = %d\n", a, b, a * b); // 30
#     printf("Division: %d / %d = %d\n", a, b, a / b);      // 3 (integer division)
#     printf("Modulo: %d %% %d = %d\n", a, b, a % b);       // 1 (remainder)
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Relational Operators

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int x = 5, y = 10;
#
#     printf("x == y: %d\n", x == y);  // 0 (false)
#     printf("x != y: %d\n", x != y);  // 1 (true)
#     printf("x < y: %d\n", x < y);    // 1 (true)
#     printf("x > y: %d\n", x > y);    // 0 (false)
#     printf("x <= y: %d\n", x <= y);  // 1 (true)
#     printf("x >= y: %d\n", x >= y);  // 0 (false)
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int a = 1, b = 0;
#
#     printf("a && b (AND): %d\n", a && b);    // 0 (false)
#     printf("a || b (OR): %d\n", a || b);     // 1 (true)
#     printf("!a (NOT): %d\n", !a);            // 0 (false)
#     printf("!b (NOT): %d\n", !b);            // 1 (true)
#
#     // Practical example
#     int age = 25, has_license = 1;
#     if (age >= 18 && has_license) {
#         printf("Can drive\n");
#     }
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Bitwise Operators

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int a = 5;      // Binary: 0101
#     int b = 3;      // Binary: 0011
#
#     printf("a & b (AND): %d\n", a & b);     // 1 (0001)
#     printf("a | b (OR): %d\n", a | b);      // 7 (0111)
#     printf("a ^ b (XOR): %d\n", a ^ b);     // 6 (0110)
#     printf("~a (NOT): %d\n", ~a);           // -6
#     printf("a << 1 (Left shift): %d\n", a << 1);   // 10 (1010)
#     printf("a >> 1 (Right shift): %d\n", a >> 1);  // 2 (0010)
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Assignment & Compound Operators

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int x = 10;
#
#     x += 5;     // x = x + 5;  → 15
#     printf("After += 5: %d\n", x);
#
#     x -= 3;     // x = x - 3;  → 12
#     printf("After -= 3: %d\n", x);
#
#     x *= 2;     // x = x * 2;  → 24
#     printf("After *= 2: %d\n", x);
#
#     x /= 4;     // x = x / 4;  → 6
#     printf("After /= 4: %d\n", x);
#
#     x %= 4;     // x = x % 4;  → 2
#     printf("After %%= 4: %d\n", x);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Increment & Decrement Operators

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int a = 5;
#
#     // Pre-increment: increment first, then use
#     printf("++a: %d\n", ++a);  // 6
#
#     // Post-increment: use first, then increment
#     printf("a++: %d\n", a++);  // 6
#     printf("a after post-increment: %d\n", a);  // 7
#
#     // Pre-decrement
#     printf("--a: %d\n", --a);  // 6
#
#     // Post-decrement
#     printf("a--: %d\n", a--);  // 6
#     printf("a after post-decrement: %d\n", a);  // 5
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Operator Precedence

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     // Multiplication and division before addition and subtraction
#     int result1 = 2 + 3 * 4;  // 14 (not 20)
#     printf("2 + 3 * 4 = %d\n", result1);
#
#     // Use parentheses for clarity
#     int result2 = (2 + 3) * 4;  // 20
#     printf("(2 + 3) * 4 = %d\n", result2);
#
#     // Precedence: () > * / % > + - > < > <= >= > == != > && > ||
#     int result3 = 5 > 3 && 2 < 4;  // 1 (true)
#     printf("5 > 3 && 2 < 4 = %d\n", result3);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Quiz 1: Arithmetic Operators

# %% [markdown]
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ What is the result of 17 % 5?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="0">
#       <span>3</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="1">
#       <span>2</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="2">
#       <span>2</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="3">
#       <span>4</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2: Logical Operators

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What is the result of (1 && 0) || 1?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="0">
#       <span>1 (true)</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="1">
#       <span>0 (false)</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="2">
#       <span>2</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="3">
#       <span>Undefined</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3: Bitwise Operators

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is 5 & 3 in binary (5 = 0101, 3 = 0011)?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="0">
#       <span>7 (0111)</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="1">
#       <span>1 (0001)</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="2">
#       <span>6 (0110)</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="3">
#       <span>8 (1000)</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4: Operator Precedence

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What is the result of 2 + 3 * 4 - 1?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="0">
#       <span>13</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="1">
#       <span>19</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="2">
#       <span>23</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="3">
#       <span>11</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5: Increment Operators

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is the difference between ++x and x++?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="0">
#       <span>No difference</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="1">
#       <span>++x increments first then returns, x++ returns then increments</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="2">
#       <span>x++ is faster</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="3">
#       <span>++x only works with integers</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
