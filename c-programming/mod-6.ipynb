# %% [markdown]
# # Functions

# %% [markdown]
# ## Function Declaration & Definition

# %% [markdown]
# ```c
# #include <stdio.h>
#
# // Function declaration (prototype)
# int add(int a, int b);
#
# int main() {
#     int result = add(5, 3);
#     printf("Result: %d\n", result);
#     return 0;
# }
#
# // Function definition
# int add(int a, int b) {
#     return a + b;
# }
# ```

# %% [markdown]
# ## Function Parameters & Return Values

# %% [markdown]
# ```c
# #include <stdio.h>
#
# // Function with no parameters, no return value
# void greet() {
#     printf("Hello!\n");
# }
#
# // Function with parameters, no return value
# void printSum(int a, int b) {
#     printf("Sum: %d\n", a + b);
# }
#
# // Function with parameters and return value
# int multiply(int a, int b) {
#     return a * b;
# }
#
# // Function with no parameters, with return value
# int getAge() {
#     return 25;
# }
#
# int main() {
#     greet();
#     printSum(10, 20);
#     int product = multiply(4, 5);
#     printf("Product: %d\n", product);
#     return 0;
# }
# ```

# %% [markdown]
# ## Pass by Value

# %% [markdown]
# ```c
# #include <stdio.h>
#
# void increment(int x) {
#     x++;  // Only increments the copy
# }
#
# int main() {
#     int num = 5;
#     increment(num);
#     printf("num: %d\n", num);  // Still 5, not 6
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Multiple Return Values (using pointers)

# %% [markdown]
# ```c
# #include <stdio.h>
#
# // Function that modifies variables through pointers
# void getMinMax(int a, int b, int *min, int *max) {
#     if (a < b) {
#         *min = a;
#         *max = b;
#     } else {
#         *min = b;
#         *max = a;
#     }
# }
#
# int main() {
#     int minimum, maximum;
#     getMinMax(10, 5, &minimum, &maximum);
#     printf("Min: %d, Max: %d\n", minimum, maximum);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Recursion

# %% [markdown]
# ```c
# #include <stdio.h>
#
# // Calculate factorial recursively
# int factorial(int n) {
#     if (n <= 1) {
#         return 1;  // Base case
#     }
#     return n * factorial(n - 1);  // Recursive case
# }
#
# // Calculate Fibonacci number
# int fibonacci(int n) {
#     if (n <= 1) {
#         return n;
#     }
#     return fibonacci(n - 1) + fibonacci(n - 2);
# }
#
# int main() {
#     printf("Factorial of 5: %d\n", factorial(5));
#     printf("Fibonacci of 6: %d\n", fibonacci(6));
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Scope & Local Variables

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int globalVar = 10;  // Global variable
#
# void function1() {
#     int localVar = 20;  // Local to function1
#     printf("Local: %d, Global: %d\n", localVar, globalVar);
# }
#
# void function2() {
#     // localVar is not accessible here
#     printf("Global: %d\n", globalVar);
# }
#
# int main() {
#     function1();
#     function2();
#     // localVar is not accessible here either
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Static Variables

# %% [markdown]
# ```c
# #include <stdio.h>
#
# void counter() {
#     static int count = 0;  // Initialized only once
#     count++;
#     printf("Count: %d\n", count);
# }
#
# int main() {
#     counter();  // Count: 1
#     counter();  // Count: 2
#     counter();  // Count: 3
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Quiz 1: Function Declaration

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is a function prototype?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="0">
#       <span>The function definition</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="1">
#       <span>A declaration that tells the compiler about the function</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="2">
#       <span>A function that returns nothing</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="3">
#       <span>A function with no parameters</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2: Pass by Value

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What happens when you pass a variable to a function in C?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="0">
#       <span>A copy of the value is passed</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="1">
#       <span>The variable itself is passed</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="2">
#       <span>The memory address is passed</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="3">
#       <span>Nothing is passed</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3: Recursion

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is essential for a recursive function to avoid infinite recursion?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="0">
#       <span>A loop</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="1">
#       <span>A base case</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="2">
#       <span>A return statement</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="3">
#       <span>Global variables</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4: Scope

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ Where can a local variable be accessed?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="0">
#       <span>Only within the function where it's declared</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="1">
#       <span>In any function</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="2">
#       <span>In the main function only</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="3">
#       <span>Everywhere in the program</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5: Static Variables

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ How many times is a static variable initialized?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="0">
#       <span>Every time the function is called</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="1">
#       <span>Only once, when the program starts</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="2">
#       <span>Never</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="3">
#       <span>Twice</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
