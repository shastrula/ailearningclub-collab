# %% [markdown]
# # Variables, Data Types & Constants

# %% [markdown]
# ## Basic Data Types

# %% [markdown]
# C provides several fundamental data types:
#
# ```c
# #include <stdio.h>
#
# int main() {
#     int age = 25;              // Integer: -2147483648 to 2147483647
#     float height = 5.9;        // Floating-point: ~6-7 decimal places
#     double weight = 72.5;      // Double precision: ~15 decimal places
#     char grade = 'A';          // Single character
#
#     printf("Age: %d\n", age);
#     printf("Height: %.1f\n", height);
#     printf("Weight: %.1f\n", weight);
#     printf("Grade: %c\n", grade);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Variable Declaration & Initialization

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     // Declaration without initialization
#     int x;
#
#     // Declaration with initialization
#     int y = 10;
#
#     // Multiple declarations
#     int a = 5, b = 10, c = 15;
#
#     // Using variables
#     int sum = a + b + c;
#     printf("Sum: %d\n", sum);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## The sizeof Operator

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     printf("Size of int: %lu bytes\n", sizeof(int));
#     printf("Size of float: %lu bytes\n", sizeof(float));
#     printf("Size of double: %lu bytes\n", sizeof(double));
#     printf("Size of char: %lu bytes\n", sizeof(char));
#
#     // Typical output on 64-bit systems:
#     // Size of int: 4 bytes
#     // Size of float: 4 bytes
#     // Size of double: 8 bytes
#     // Size of char: 1 byte
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Constants

# %% [markdown]
# Constants are variables whose values cannot be changed after initialization:
#
# ```c
# #include <stdio.h>
#
# int main() {
#     // Using const keyword
#     const int MAX_USERS = 100;
#     const float PI = 3.14159;
#
#     // This would cause a compilation error:
#     // MAX_USERS = 200;  // Error: assignment of read-only variable
#
#     printf("Max users: %d\n", MAX_USERS);
#     printf("Pi: %.5f\n", PI);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Naming Conventions & Best Practices

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     // Good variable names (descriptive, lowercase with underscores)
#     int student_age = 20;
#     float average_score = 85.5;
#     char first_initial = 'J';
#
#     // Constants in UPPERCASE
#     const int MAX_ATTEMPTS = 3;
#     const float GRAVITY = 9.8;
#
#     // Avoid single letters except for loop counters
#     // int x = 10;  // Not descriptive
#     // int num_items = 10;  // Better
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Quiz 1: Data Types

# %% [markdown]
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ Which data type should you use for storing a person's age?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="0">
#       <span>float</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="1">
#       <span>char</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="2">
#       <span>int</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4729183" value="3">
#       <span>double</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2: sizeof Operator

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What does `sizeof(int)` typically return on a 64-bit system?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="0">
#       <span>2 bytes</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="1">
#       <span>4 bytes</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="2">
#       <span>8 bytes</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="3">
#       <span>16 bytes</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3: Constants

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What happens if you try to modify a const variable?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5829374" value="0">
#       <span>Compilation error</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5829374" value="1">
#       <span>Runtime error</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5829374" value="2">
#       <span>The value changes silently</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5829374" value="3">
#       <span>Nothing happens</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4: Variable Initialization

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is the value of an uninitialized int variable?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7291846" value="0">
#       <span>Always 0</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7291846" value="1">
#       <span>Undefined (garbage value)</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7291846" value="2">
#       <span>Always -1</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7291846" value="3">
#       <span>Always NULL</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5: Float vs Double

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is the main difference between float and double?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9374821" value="0">
#       <span>float is faster</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9374821" value="1">
#       <span>double has more precision and uses more memory</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9374821" value="2">
#       <span>double can only store integers</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9374821" value="3">
#       <span>They are identical</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
