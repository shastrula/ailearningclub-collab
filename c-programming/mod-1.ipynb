# %% [markdown]
# # Introduction to C & Setup

# %% [markdown]
# ## History & Why C Matters

# %% [markdown]
# C revolutionized programming by providing a balance between high-level abstraction and low-level hardware control. It's used in operating systems, embedded systems, databases, and performance-critical applications. Understanding C teaches you how computers actually work.

# %% [markdown]
# ## Setting Up Your Environment

# %% [markdown]
# ### On macOS
# ```c
# // Install Xcode Command Line Tools
# // Open Terminal and run:
# // xcode-select --install
#
# // Verify gcc is installed
# gcc --version
# ```
#
# ### On Linux (Ubuntu/Debian)
# ```c
# // Install gcc and build tools
# // sudo apt-get update
# // sudo apt-get install build-essential
#
# // Verify installation
# gcc --version
# ```
#
# ### On Windows
# ```c
# // Download MinGW from mingw-w64.org
# // Add to PATH
# // Verify: gcc --version
# ```

# %% [markdown]
# ## Your First Program: Hello World

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     printf("Hello, World!\n");
#     return 0;
# }
# ```
#
# Save this as `hello.c` and compile:
# ```c
# // gcc hello.c -o hello
# // ./hello
# // Output: Hello, World!
# ```

# %% [markdown]
# ## Understanding the Compilation Process

# %% [markdown]
# ```c
# // Source code (hello.c) → Preprocessor → Compiler → Assembler → Linker → Executable
#
# // Step 1: Preprocessing (handles #include, #define)
# // gcc -E hello.c
#
# // Step 2: Compilation (converts to assembly)
# // gcc -S hello.c
#
# // Step 3: Assembly (converts to object code)
# // gcc -c hello.c
#
# // Step 4: Linking (creates executable)
# // gcc hello.o -o hello
# ```

# %% [markdown]
# ## Common GCC Flags

# %% [markdown]
# ```c
# // gcc -Wall hello.c -o hello        // Enable all warnings
# // gcc -g hello.c -o hello           // Include debug symbols
# // gcc -O2 hello.c -o hello          // Optimize for speed
# // gcc -std=c99 hello.c -o hello     // Use C99 standard
# ```

# %% [markdown]
# ## Program Structure

# %% [markdown]
# ```c
# #include <stdio.h>      // Include standard I/O library
#
# int main() {            // Entry point of program
#     // Your code here
#     return 0;           // Return 0 to indicate success
# }
# ```

# %% [markdown]
# ## Quiz 1: C History

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ Who created the C programming language?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374291" value="0">
#       <span>Bjarne Stroustrup</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374291" value="1">
#       <span>Dennis Ritchie</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374291" value="2">
#       <span>Guido van Rossum</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374291" value="3">
#       <span>James Gosling</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2: Compilation

# %% [markdown]
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ What is the correct order of the compilation process?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5927461" value="0">
#       <span>Linker → Assembler → Compiler → Preprocessor</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5927461" value="1">
#       <span>Compiler → Preprocessor → Assembler → Linker</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5927461" value="2">
#       <span>Preprocessor → Compiler → Assembler → Linker</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5927461" value="3">
#       <span>Assembler → Compiler → Preprocessor → Linker</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3: Hello World

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What does `#include <stdio.h>` do?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7461829" value="0">
#       <span>Includes the standard input/output library</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7461829" value="1">
#       <span>Defines the main function</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7461829" value="2">
#       <span>Compiles the program</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7461829" value="3">
#       <span>Declares variables</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4: GCC Flags

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ Which flag enables all compiler warnings?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2847561" value="0">
#       <span>-O2</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2847561" value="1">
#       <span>-Wall</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2847561" value="2">
#       <span>-g</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2847561" value="3">
#       <span>-std=c99</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5: Return Value

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What does `return 0;` in main() indicate?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9182746" value="0">
#       <span>The program executed successfully</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9182746" value="1">
#       <span>The program failed</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9182746" value="2">
#       <span>The program should restart</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9182746" value="3">
#       <span>The program should print output</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
