# %% [markdown]
# # Preprocessor & Build

# %% [markdown]
# ## #include Directive

# %% [markdown]
# ```c
# // Include standard library headers
# #include <stdio.h>      // System header (angle brackets)
# #include <stdlib.h>
# #include <string.h>
#
# // Include custom headers
# #include "myheader.h"   // Local header (quotes)
#
# int main() {
#     printf("Hello\n");
#     return 0;
# }
# ```

# %% [markdown]
# ## #define Macro

# %% [markdown]
# ```c
# #include <stdio.h>
#
# // Simple macro
# #define PI 3.14159
# #define MAX_SIZE 100
#
# // Macro with parameters
# #define ADD(a, b) ((a) + (b))
# #define SQUARE(x) ((x) * (x))
#
# int main() {
#     float area = PI * SQUARE(5);
#     printf("Area: %.2f\n", area);
#
#     int sum = ADD(10, 20);
#     printf("Sum: %d\n", sum);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Conditional Compilation

# %% [markdown]
# ```c
# #include <stdio.h>
#
# #define DEBUG 1
#
# int main() {
#     #if DEBUG
#         printf("Debug mode ON\n");
#     #else
#         printf("Debug mode OFF\n");
#     #endif
#
#     #ifdef DEBUG
#         printf("DEBUG is defined\n");
#     #endif
#
#     #ifndef RELEASE
#         printf("Not in release mode\n");
#     #endif
#
#     return 0;
# }
# ```

# %% [markdown]
# ## #undef Directive

# %% [markdown]
# ```c
# #include <stdio.h>
#
# #define VALUE 10
#
# int main() {
#     printf("VALUE: %d\n", VALUE);
#
#     #undef VALUE
#
#     // VALUE is no longer defined
#     // printf("%d\n", VALUE);  // Error
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Predefined Macros

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     printf("File: %s\n", __FILE__);      // Current file name
#     printf("Line: %d\n", __LINE__);      // Current line number
#     printf("Date: %s\n", __DATE__);      // Compilation date
#     printf("Time: %s\n", __TIME__);      // Compilation time
#     printf("Function: %s\n", __func__);  // Current function name
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Header Files

# %% [markdown]
# ```c
# // mymath.h
# #ifndef MYMATH_H
# #define MYMATH_H
#
# int add(int a, int b);
# int subtract(int a, int b);
# int multiply(int a, int b);
#
# #endif
# ```
#
# ```c
# // mymath.c
# #include "mymath.h"
#
# int add(int a, int b) {
#     return a + b;
# }
#
# int subtract(int a, int b) {
#     return a - b;
# }
#
# int multiply(int a, int b) {
#     return a * b;
# }
# ```
#
# ```c
# // main.c
# #include <stdio.h>
# #include "mymath.h"
#
# int main() {
#     printf("Add: %d\n", add(5, 3));
#     printf("Subtract: %d\n", subtract(5, 3));
#     printf("Multiply: %d\n", multiply(5, 3));
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Makefile Example

# %% [markdown]
# ```makefile
# # Makefile
# CC = gcc
# CFLAGS = -Wall -g
# TARGET = program
#
# SOURCES = main.c mymath.c
# OBJECTS = $(SOURCES:.c=.o)
#
# $(TARGET): $(OBJECTS)
# 	$(CC) $(CFLAGS) -o $(TARGET) $(OBJECTS)
#
# %.o: %.c
# 	$(CC) $(CFLAGS) -c $< -o $@
#
# clean:
# 	rm -f $(OBJECTS) $(TARGET)
#
# run: $(TARGET)
# 	./$(TARGET)
#
# .PHONY: clean run
# ```

# %% [markdown]
# ## Compilation Process

# %% [markdown]
# ```c
# // Step 1: Preprocessing
# // gcc -E main.c > main.i
#
# // Step 2: Compilation
# // gcc -S main.i
#
# // Step 3: Assembly
# // gcc -c main.s
#
# // Step 4: Linking
# // gcc main.o -o program
#
# // Or all in one:
# // gcc -Wall -g main.c -o program
# ```

# %% [markdown]
# ## Common Compiler Flags

# %% [markdown]
# ```c
# // -Wall: Enable all warnings
# // -g: Include debug symbols
# // -O2: Optimize for speed
# // -std=c99: Use C99 standard
# // -D: Define a macro
# // -I: Add include directory
# // -L: Add library directory
# // -l: Link a library
#
# // Example:
# // gcc -Wall -g -O2 -std=c99 main.c -o program
# ```

# %% [markdown]
# ## Practical Example: Configuration Header

# %% [markdown]
# ```c
# // config.h
# #ifndef CONFIG_H
# #define CONFIG_H
#
# #define APP_NAME "MyApp"
# #define APP_VERSION "1.0"
# #define DEBUG 1
#
# #if DEBUG
#     #define LOG(msg) printf("[DEBUG] %s\n", msg)
# #else
#     #define LOG(msg)
# #endif
#
# #endif
# ```
#
# ```c
# // main.c
# #include <stdio.h>
# #include "config.h"
#
# int main() {
#     printf("%s v%s\n", APP_NAME, APP_VERSION);
#     LOG("Application started");
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Quiz 1: #include

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is the difference between #include <stdio.h> and #include "myheader.h"?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="0">
#       <span>No difference</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="1">
#       <span>Angle brackets search system paths, quotes search local directory first</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="2">
#       <span>Quotes are for functions, angle brackets for variables</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="3">
#       <span>Angle brackets are deprecated</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2: #define Macro

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What does #define do?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="0">
#       <span>Creates a macro that is replaced during preprocessing</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="1">
#       <span>Declares a variable</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="2">
#       <span>Defines a function</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="3">
#       <span>Includes a header file</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3: Conditional Compilation

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What does #ifdef do?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="0">
#       <span>Includes a file</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="1">
#       <span>Checks if a macro is defined</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="2">
#       <span>Defines a macro</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="3">
#       <span>Undefines a macro</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4: Header Guards

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What is the purpose of header guards (#ifndef)?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="0">
#       <span>Prevent multiple inclusion of the same header</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="1">
#       <span>Protect against compilation errors</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="2">
#       <span>Speed up compilation</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="3">
#       <span>Define constants</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5: Compiler Flags

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What does the -Wall flag do?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="0">
#       <span>Optimizes the code</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="1">
#       <span>Enables all compiler warnings</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="2">
#       <span>Includes debug symbols</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="3">
#       <span>Links all libraries</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
