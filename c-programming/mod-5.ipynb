# %% [markdown]
# # Loops

# %% [markdown]
# ## for Loop

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     // Print numbers 1 to 5
#     for (int i = 1; i <= 5; i++) {
#         printf("%d ", i);
#     }
#     printf("\n");
#
#     // Syntax: for (initialization; condition; increment)
#     // initialization: runs once before loop
#     // condition: checked before each iteration
#     // increment: runs after each iteration
#
#     return 0;
# }
# ```

# %% [markdown]
# ## while Loop

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int i = 1;
#
#     while (i <= 5) {
#         printf("%d ", i);
#         i++;
#     }
#     printf("\n");
#
#     // Useful when you don't know how many iterations needed
#     int sum = 0, num = 0;
#     while (num < 10) {
#         sum += num;
#         num++;
#     }
#     printf("Sum: %d\n", sum);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## do-while Loop

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int i = 1;
#
#     // Executes at least once, even if condition is false
#     do {
#         printf("%d ", i);
#         i++;
#     } while (i <= 5);
#     printf("\n");
#
#     // Useful for menu-driven programs
#     int choice;
#     do {
#         printf("Enter 1 to continue, 0 to exit: ");
#         scanf("%d", &choice);
#     } while (choice != 0);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## break Statement

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     // Exit loop when condition is met
#     for (int i = 1; i <= 10; i++) {
#         if (i == 5) {
#             break;  // Exit loop
#         }
#         printf("%d ", i);
#     }
#     printf("\n");  // Output: 1 2 3 4
#
#     return 0;
# }
# ```

# %% [markdown]
# ## continue Statement

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     // Skip current iteration and go to next
#     for (int i = 1; i <= 5; i++) {
#         if (i == 3) {
#             continue;  // Skip this iteration
#         }
#         printf("%d ", i);
#     }
#     printf("\n");  // Output: 1 2 4 5
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Nested Loops

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     // Print multiplication table
#     for (int i = 1; i <= 3; i++) {
#         for (int j = 1; j <= 3; j++) {
#             printf("%d ", i * j);
#         }
#         printf("\n");
#     }
#
#     // Output:
#     // 1 2 3
#     // 2 4 6
#     // 3 6 9
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Practical Examples

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     // Calculate factorial
#     int n = 5;
#     int factorial = 1;
#     for (int i = 1; i <= n; i++) {
#         factorial *= i;
#     }
#     printf("Factorial of %d: %d\n", n, factorial);
#
#     // Find sum of digits
#     int num = 12345;
#     int sum = 0;
#     while (num > 0) {
#         sum += num % 10;
#         num /= 10;
#     }
#     printf("Sum of digits: %d\n", sum);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Quiz 1: for Loop

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ How many times will this loop execute? for (int i = 0; i < 5; i++)</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="0">
#       <span>5 times</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="1">
#       <span>4 times</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="2">
#       <span>6 times</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="3">
#       <span>Infinite times</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2: while Loop

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is the key difference between while and do-while?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="0">
#       <span>while is faster</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="1">
#       <span>do-while executes at least once</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="2">
#       <span>while can't use break</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="3">
#       <span>They are identical</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3: break Statement

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What will print? for (int i = 1; i <= 5; i++) { if (i == 3) break; printf("%d ", i); }</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="0">
#       <span>1 2</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="1">
#       <span>1 2 3</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="2">
#       <span>1 2 3 4 5</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="3">
#       <span>Nothing</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4: continue Statement

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What will print? for (int i = 1; i <= 5; i++) { if (i == 3) continue; printf("%d ", i); }</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="0">
#       <span>1 2 3 4 5</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="1">
#       <span>1 2 4 5</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="2">
#       <span>1 2</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="3">
#       <span>2 3 4 5</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5: Nested Loops

# %% [markdown]
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ How many times will the inner loop execute in nested loops: for (int i = 0; i < 3; i++) for (int j = 0; j < 2; j++)?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="0">
#       <span>3 times</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="1">
#       <span>2 times</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="2">
#       <span>6 times</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="3">
#       <span>5 times</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
