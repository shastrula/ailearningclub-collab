# %% [markdown]
# # Pointers

# %% [markdown]
# ## Pointer Declaration & Initialization

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int x = 10;
#     int *ptr;  // Declare a pointer to int
#
#     ptr = &x;  // ptr now holds the address of x
#
#     printf("Value of x: %d\n", x);
#     printf("Address of x: %p\n", &x);
#     printf("Value of ptr: %p\n", ptr);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Dereferencing Pointers

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int x = 10;
#     int *ptr = &x;
#
#     // Dereference: access the value at the address
#     printf("Value at address: %d\n", *ptr);  // 10
#
#     // Modify through pointer
#     *ptr = 20;
#     printf("x is now: %d\n", x);  // 20
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Pointer Arithmetic

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int arr[] = {10, 20, 30, 40, 50};
#     int *ptr = arr;  // ptr points to first element
#
#     printf("First element: %d\n", *ptr);      // 10
#     printf("Second element: %d\n", *(ptr + 1)); // 20
#     printf("Third element: %d\n", *(ptr + 2));  // 30
#
#     // Increment pointer
#     ptr++;
#     printf("After ptr++: %d\n", *ptr);  // 20
#
#     // Pointer difference
#     int *ptr1 = &arr[0];
#     int *ptr2 = &arr[3];
#     printf("Difference: %ld\n", ptr2 - ptr1);  // 3
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Pointers to Pointers

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int x = 10;
#     int *ptr = &x;
#     int **pptr = &ptr;  // Pointer to pointer
#
#     printf("x: %d\n", x);
#     printf("*ptr: %d\n", *ptr);
#     printf("**pptr: %d\n", **pptr);
#
#     // Modify through pointer to pointer
#     **pptr = 20;
#     printf("x is now: %d\n", x);  // 20
#
#     return 0;
# }
# ```

# %% [markdown]
# ## NULL Pointer

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int *ptr = NULL;  // NULL pointer (doesn't point to anything)
#
#     // Always check before dereferencing
#     if (ptr != NULL) {
#         printf("Value: %d\n", *ptr);
#     } else {
#         printf("Pointer is NULL\n");
#     }
#
#     // Dereferencing NULL causes crash
#     // printf("%d\n", *ptr);  // CRASH!
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Pointers and Arrays

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int arr[] = {10, 20, 30, 40, 50};
#     int *ptr = arr;  // Array name is a pointer to first element
#
#     // Access array elements using pointer
#     for (int i = 0; i < 5; i++) {
#         printf("%d ", *(ptr + i));
#     }
#     printf("\n");
#
#     // Equivalent to array indexing
#     printf("arr[2] = %d\n", arr[2]);
#     printf("*(ptr + 2) = %d\n", *(ptr + 2));
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Pointers and Functions

# %% [markdown]
# ```c
# #include <stdio.h>
#
# // Pass by reference using pointers
# void swap(int *a, int *b) {
#     int temp = *a;
#     *a = *b;
#     *b = temp;
# }
#
# // Function returning a pointer
# int* getMax(int *a, int *b) {
#     return (*a > *b) ? a : b;
# }
#
# int main() {
#     int x = 5, y = 10;
#
#     printf("Before swap: x=%d, y=%d\n", x, y);
#     swap(&x, &y);
#     printf("After swap: x=%d, y=%d\n", x, y);
#
#     int *max = getMax(&x, &y);
#     printf("Max: %d\n", *max);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Void Pointers

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int x = 10;
#     float y = 3.14;
#
#     void *ptr;  // Generic pointer
#
#     ptr = &x;
#     printf("Integer: %d\n", *(int*)ptr);  // Cast to int*
#
#     ptr = &y;
#     printf("Float: %.2f\n", *(float*)ptr);  // Cast to float*
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Quiz 1: Address-of Operator

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What does the & operator do?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="0">
#       <span>Dereferences a pointer</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="1">
#       <span>Gets the address of a variable</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="2">
#       <span>Declares a pointer</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="3">
#       <span>Performs bitwise AND</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2: Dereferencing

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What does the * operator do when used with a pointer?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="0">
#       <span>Accesses the value at the address</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="1">
#       <span>Gets the address</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="2">
#       <span>Multiplies the pointer</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="3">
#       <span>Declares a pointer</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3: Pointer Arithmetic

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ If ptr points to an int and you do ptr++, how many bytes does it advance?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="0">
#       <span>1 byte</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="1">
#       <span>4 bytes (size of int)</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="2">
#       <span>8 bytes</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="3">
#       <span>Depends on the system</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4: NULL Pointer

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is a NULL pointer?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="0">
#       <span>A pointer to address 0</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="1">
#       <span>A pointer that doesn't point to anything valid</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="2">
#       <span>A pointer to NULL variable</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="3">
#       <span>An uninitialized pointer</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5: Pointer to Pointer

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What does ** do with a pointer to pointer?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="0">
#       <span>Dereferences twice to get the original value</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="1">
#       <span>Multiplies the pointer</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="2">
#       <span>Gets the address of the pointer</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="3">
#       <span>Declares a pointer to pointer</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
