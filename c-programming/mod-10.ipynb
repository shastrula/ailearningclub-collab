# %% [markdown]
# # Dynamic Memory

# %% [markdown]
# ## malloc Function

# %% [markdown]
# ```c
# #include <stdio.h>
# #include <stdlib.h>
#
# int main() {
#     // Allocate memory for 5 integers
#     int *ptr = (int*)malloc(5 * sizeof(int));
#
#     if (ptr == NULL) {
#         printf("Memory allocation failed\n");
#         return 1;
#     }
#
#     // Use the allocated memory
#     for (int i = 0; i < 5; i++) {
#         ptr[i] = i * 10;
#     }
#
#     // Print values
#     for (int i = 0; i < 5; i++) {
#         printf("%d ", ptr[i]);
#     }
#     printf("\n");
#
#     // Free the memory
#     free(ptr);
#     ptr = NULL;  // Good practice
#
#     return 0;
# }
# ```

# %% [markdown]
# ## calloc Function

# %% [markdown]
# ```c
# #include <stdio.h>
# #include <stdlib.h>
#
# int main() {
#     // calloc: allocates and initializes to 0
#     int *ptr = (int*)calloc(5, sizeof(int));
#
#     if (ptr == NULL) {
#         printf("Memory allocation failed\n");
#         return 1;
#     }
#
#     // All elements are initialized to 0
#     for (int i = 0; i < 5; i++) {
#         printf("%d ", ptr[i]);  // 0 0 0 0 0
#     }
#     printf("\n");
#
#     free(ptr);
#     ptr = NULL;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## realloc Function

# %% [markdown]
# ```c
# #include <stdio.h>
# #include <stdlib.h>
#
# int main() {
#     // Allocate initial memory
#     int *ptr = (int*)malloc(3 * sizeof(int));
#
#     ptr[0] = 10;
#     ptr[1] = 20;
#     ptr[2] = 30;
#
#     // Resize to 5 integers
#     ptr = (int*)realloc(ptr, 5 * sizeof(int));
#
#     if (ptr == NULL) {
#         printf("Reallocation failed\n");
#         return 1;
#     }
#
#     ptr[3] = 40;
#     ptr[4] = 50;
#
#     for (int i = 0; i < 5; i++) {
#         printf("%d ", ptr[i]);
#     }
#     printf("\n");
#
#     free(ptr);
#     ptr = NULL;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Memory Leaks

# %% [markdown]
# ```c
# #include <stdio.h>
# #include <stdlib.h>
#
# // BAD: Memory leak
# void leaky_function() {
#     int *ptr = (int*)malloc(100 * sizeof(int));
#     // ... use ptr ...
#     // Forgot to free!
# }
#
# // GOOD: Proper memory management
# void good_function() {
#     int *ptr = (int*)malloc(100 * sizeof(int));
#     // ... use ptr ...
#     free(ptr);
#     ptr = NULL;
# }
#
# int main() {
#     good_function();
#     return 0;
# }
# ```

# %% [markdown]
# ## Dynamic Arrays

# %% [markdown]
# ```c
# #include <stdio.h>
# #include <stdlib.h>
#
# int main() {
#     int n;
#     printf("Enter array size: ");
#     scanf("%d", &n);
#
#     // Allocate array of size n
#     int *arr = (int*)malloc(n * sizeof(int));
#
#     if (arr == NULL) {
#         printf("Memory allocation failed\n");
#         return 1;
#     }
#
#     // Input values
#     for (int i = 0; i < n; i++) {
#         printf("Enter element %d: ", i);
#         scanf("%d", &arr[i]);
#     }
#
#     // Print values
#     printf("Array: ");
#     for (int i = 0; i < n; i++) {
#         printf("%d ", arr[i]);
#     }
#     printf("\n");
#
#     free(arr);
#     arr = NULL;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Dynamic 2D Arrays

# %% [markdown]
# ```c
# #include <stdio.h>
# #include <stdlib.h>
#
# int main() {
#     int rows = 3, cols = 4;
#
#     // Allocate array of pointers
#     int **matrix = (int**)malloc(rows * sizeof(int*));
#
#     // Allocate each row
#     for (int i = 0; i < rows; i++) {
#         matrix[i] = (int*)malloc(cols * sizeof(int));
#     }
#
#     // Initialize and print
#     for (int i = 0; i < rows; i++) {
#         for (int j = 0; j < cols; j++) {
#             matrix[i][j] = i * cols + j;
#             printf("%d ", matrix[i][j]);
#         }
#         printf("\n");
#     }
#
#     // Free memory
#     for (int i = 0; i < rows; i++) {
#         free(matrix[i]);
#     }
#     free(matrix);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Dynamic Structures

# %% [markdown]
# ```c
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
#
# typedef struct {
#     int id;
#     char name[50];
#     float salary;
# } Employee;
#
# int main() {
#     int n;
#     printf("Enter number of employees: ");
#     scanf("%d", &n);
#
#     // Allocate array of structures
#     Employee *employees = (Employee*)malloc(n * sizeof(Employee));
#
#     if (employees == NULL) {
#         printf("Memory allocation failed\n");
#         return 1;
#     }
#
#     // Input data
#     for (int i = 0; i < n; i++) {
#         printf("Employee %d ID: ", i + 1);
#         scanf("%d", &employees[i].id);
#         printf("Name: ");
#         scanf("%s", employees[i].name);
#         printf("Salary: ");
#         scanf("%f", &employees[i].salary);
#     }
#
#     // Print data
#     for (int i = 0; i < n; i++) {
#         printf("%d %s %.2f\n",
#                employees[i].id,
#                employees[i].name,
#                employees[i].salary);
#     }
#
#     free(employees);
#     employees = NULL;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Best Practices

# %% [markdown]
# ```c
# #include <stdio.h>
# #include <stdlib.h>
#
# int main() {
#     // 1. Always check if allocation succeeded
#     int *ptr = (int*)malloc(100 * sizeof(int));
#     if (ptr == NULL) {
#         printf("Allocation failed\n");
#         return 1;
#     }
#
#     // 2. Use sizeof to avoid hardcoding sizes
#     // Good: malloc(n * sizeof(int))
#     // Bad: malloc(n * 4)
#
#     // 3. Free memory when done
#     free(ptr);
#
#     // 4. Set to NULL after freeing
#     ptr = NULL;
#
#     // 5. Don't use memory after freeing
#     // printf("%d\n", *ptr);  // DANGER!
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Quiz 1: malloc

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What does malloc return if allocation fails?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="0">
#       <span>0</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="1">
#       <span>NULL</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="2">
#       <span>-1</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="3">
#       <span>An error code</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2: calloc vs malloc

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What is the main difference between calloc and malloc?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="0">
#       <span>calloc initializes memory to 0, malloc doesn't</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="1">
#       <span>malloc is faster</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="2">
#       <span>calloc can't allocate arrays</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="3">
#       <span>They are identical</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3: Memory Leak

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What is a memory leak?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="0">
#       <span>When a pointer is NULL</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="1">
#       <span>When allocated memory is not freed</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="2">
#       <span>When you access out of bounds</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="3">
#       <span>When malloc fails</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4: realloc

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What does realloc do?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="0">
#       <span>Resizes previously allocated memory</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="1">
#       <span>Frees memory</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="2">
#       <span>Allocates new memory</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="3">
#       <span>Initializes memory to 0</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5: sizeof in malloc

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ Why use sizeof in malloc? int *ptr = (int*)malloc(n * sizeof(int))</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="0">
#       <span>It's required by the compiler</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="1">
#       <span>To ensure correct memory allocation for the data type</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="2">
#       <span>To make the code faster</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="3">
#       <span>It's optional</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
