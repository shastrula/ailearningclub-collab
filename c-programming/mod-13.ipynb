# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [The C Programming Language (K&R)](https://en.wikipedia.org/wiki/The_C_Programming_Language) — The definitive C book
# - [C Reference (cppreference.com)](https://en.cppreference.com/w/c) — Standard library reference
# - [Learn C (learn-c.org)](https://www.learn-c.org/) — Free interactive tutorials
# - [Beej's Guide to C](https://beej.us/guide/bgc/) — Beginner-friendly online book
# - [CS50 (Harvard)](https://cs50.harvard.edu/x/) — Intro CS course taught in C
# - [GCC Documentation](https://gcc.gnu.org/onlinedocs/) — GNU C Compiler reference
