# %% [markdown]
# # Control Flow

# %% [markdown]
# ## if Statement

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int age = 18;
#
#     if (age >= 18) {
#         printf("You are an adult\n");
#     }
#
#     return 0;
# }
# ```

# %% [markdown]
# ## if-else Statement

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int score = 45;
#
#     if (score >= 50) {
#         printf("Pass\n");
#     } else {
#         printf("Fail\n");
#     }
#
#     return 0;
# }
# ```

# %% [markdown]
# ## if-else if-else Chain

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int grade = 75;
#
#     if (grade >= 90) {
#         printf("A\n");
#     } else if (grade >= 80) {
#         printf("B\n");
#     } else if (grade >= 70) {
#         printf("C\n");
#     } else if (grade >= 60) {
#         printf("D\n");
#     } else {
#         printf("F\n");
#     }
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Nested if Statements

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int age = 25;
#     int has_license = 1;
#
#     if (age >= 18) {
#         if (has_license) {
#             printf("Can drive\n");
#         } else {
#             printf("Too young to drive\n");
#         }
#     } else {
#         printf("Must be 18 to drive\n");
#     }
#
#     return 0;
# }
# ```

# %% [markdown]
# ## switch Statement

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int day = 3;
#
#     switch (day) {
#         case 1:
#             printf("Monday\n");
#             break;
#         case 2:
#             printf("Tuesday\n");
#             break;
#         case 3:
#             printf("Wednesday\n");
#             break;
#         case 4:
#             printf("Thursday\n");
#             break;
#         case 5:
#             printf("Friday\n");
#             break;
#         default:
#             printf("Weekend\n");
#     }
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Ternary Operator

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int age = 20;
#
#     // Syntax: condition ? value_if_true : value_if_false
#     char *status = (age >= 18) ? "Adult" : "Minor";
#     printf("Status: %s\n", status);
#
#     // Nested ternary
#     int score = 75;
#     char grade = (score >= 90) ? 'A' :
#                  (score >= 80) ? 'B' :
#                  (score >= 70) ? 'C' : 'F';
#     printf("Grade: %c\n", grade);
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Practical Example: Calculator

# %% [markdown]
# ```c
# #include <stdio.h>
#
# int main() {
#     int a = 10, b = 5;
#     char op = '+';
#
#     switch (op) {
#         case '+':
#             printf("%d + %d = %d\n", a, b, a + b);
#             break;
#         case '-':
#             printf("%d - %d = %d\n", a, b, a - b);
#             break;
#         case '*':
#             printf("%d * %d = %d\n", a, b, a * b);
#             break;
#         case '/':
#             if (b != 0) {
#                 printf("%d / %d = %d\n", a, b, a / b);
#             } else {
#                 printf("Cannot divide by zero\n");
#             }
#             break;
#         default:
#             printf("Invalid operator\n");
#     }
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Quiz 1: if-else

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What will print if x = 5?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="0">
#       <span>x is positive</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="1">
#       <span>x is negative</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="2">
#       <span>x is zero</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8374629" value="3">
#       <span>Nothing</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 2: switch Statement

# %% [markdown]
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ What is the purpose of `break;` in a switch statement?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="0">
#       <span>To exit the program</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="1">
#       <span>To skip the next case</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="2">
#       <span>To exit the switch block</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q5729384" value="3">
#       <span>To restart the switch</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 3: Ternary Operator

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ What does this ternary operator return? (x > 5) ? 10 : 20 when x = 3</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="0">
#       <span>10</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="1">
#       <span>20</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="2">
#       <span>3</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q9284756" value="3">
#       <span>Error</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 4: Nested if

# %% [markdown]
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What will print if age = 20 and has_license = 1?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="0">
#       <span>Can drive</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="1">
#       <span>Too young to drive</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="2">
#       <span>Must be 18 to drive</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q7384629" value="3">
#       <span>Nothing</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Quiz 5: default Case

# %% [markdown]
# <div class="quiz" data-correct="1">
#   <p class="font-semibold mb-3">❓ When does the `default` case execute in a switch?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="0">
#       <span>Always, before other cases</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="1">
#       <span>When no other case matches</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="2">
#       <span>Never</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q2947183" value="3">
#       <span>Only if break is missing</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
