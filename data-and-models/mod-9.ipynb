# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Kaggle Datasets](https://www.kaggle.com/datasets) — Free datasets
# - [Hugging Face Datasets](https://huggingface.co/datasets) — NLP/ML datasets
# - [UCI ML Repository](https://archive.ics.uci.edu/) — Classic ML datasets
