# %% [markdown]
# # Deploying Models

# %% [markdown]
# ## Model Export and Serialization

# %% [markdown]
# ### Why Export and Serialize Models?
#
# Model export and serialization are the first steps in deploying a PyTorch model. Exporting involves saving the model's architecture and weights to a file, while serialization ensures that the model can be loaded and used in different environments. This process is essential for making the model portable and reusable.
#
# ### How to Export and Serialize
#
#
#
# **Explanation:**
# - `torch.nn.Module`: Base class for all neural network modules.
# - `nn.Linear(10, 1)`: Defines a linear layer that takes 10 inputs and produces 1 output.
# - `model.state_dict()`: Returns a dictionary object that stores the model’s parameters and buffers.
# - `torch.save`: Saves the state dictionary to a file.

# %%
import torch
import torch.nn as nn

# Define a simple model
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.fc = nn.Linear(10, 1)  # Fully connected layer

    def forward(self, x):
        return self.fc(x)

# Instantiate the model
model = SimpleModel()

# Export the model
torch.save(model.state_dict(), 'model.pth')
print('Model exported successfully')

# %% [markdown]
# ## Model Loading and Inference

# %% [markdown]
# ### Why Load and Perform Inference?
#
# Once a model is exported, it can be loaded and used for inference in different environments. This involves loading the model's architecture and weights from the saved file and preparing it for making predictions. Proper loading ensures that the model behaves as expected in production.
#
# ### How to Load and Perform Inference
#
#
#
# **Explanation:**
# - `model.load_state_dict(torch.load('model.pth'))`: Loads the saved parameters into the model.
# - `model.eval()`: Sets the model to evaluation mode, which disables dropout and batch normalization layers that behave differently during training.
# - `torch.no_grad()`: Context manager that disables gradient calculations, which is useful for inference to save memory and computation.

# %%
import torch
import torch.nn as nn

# Define the same model architecture
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.fc = nn.Linear(10, 1)

    def forward(self, x):
        return self.fc(x)

# Instantiate the model
model = SimpleModel()

# Load the model weights
model.load_state_dict(torch.load('model.pth'))
model.eval()  # Set the model to evaluation mode

# Prepare a sample input
input_tensor = torch.randn(1, 10)

# Perform inference
with torch.no_grad():  # Disable gradient calculation
    output = model(input_tensor)
print('Inference output:', output)

# %% [markdown]
# ## Real-World Case Study: Deploying a Recommendation System

# %% [markdown]
# ### Company: Netflix
#
# **Problem:** Netflix needed to deploy a deep learning recommendation system to provide personalized movie suggestions to its users.
#
# **Solution:**
# - **Model Development:** Trained a deep learning model using PyTorch on a vast dataset of user interactions.
# - **Export and Serialization:** Saved the model using `torch.save`.
# - **Deployment:** The model was deployed on Netflix’s servers using a Flask API, allowing it to handle incoming requests and provide real-time recommendations.
#
# **Impact:** The deployed model significantly improved user engagement and satisfaction by providing more relevant movie suggestions.

# %% [markdown]
# ## Interactive Quizzes

# %% [markdown]
# ### Quiz 1: What is the purpose of setting the model to evaluation mode?
# - [ ] To enable dropout during inference
# - [✓] To disable training-specific behaviors
# - [ ] To increase model accuracy
# - [ ] To save the model weights
#
# ### Quiz 2: What function is used to load the model weights from a file?
# - [ ] torch.train()
# - [✓] torch.load()
# - [ ] model.save()
# - [ ] model.eval()
#
# ### Quiz 3: Which context manager should be used during inference to disable gradient calculation?
# - [ ] with torch.enable_grad():
# - [✓] with torch.no_grad():
# - [ ] with model.no_grad():
# - [ ] with torch.inference_mode():
