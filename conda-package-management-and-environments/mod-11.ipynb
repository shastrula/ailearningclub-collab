# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Conda Documentation](https://docs.conda.io/) — Official docs
# - [Conda Cheat Sheet](https://docs.conda.io/projects/conda/en/latest/user-guide/cheatsheet.html) — Quick reference
# - [Anaconda](https://www.anaconda.com/) — Data science distribution
