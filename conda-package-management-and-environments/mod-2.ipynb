# %% [markdown]
# # Conda Package Management And Environments - mod-2
#
# **Course:** conda-package-management-and-environments
#
# Run the code cells below to practice. Code is loaded from GitHub using IPython magic.
