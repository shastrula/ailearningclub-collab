# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [NumPy Documentation](https://numpy.org/doc/) — Array computing
# - [Pandas Documentation](https://pandas.pydata.org/docs/) — Data analysis
# - [NumPy for Beginners](https://numpy.org/doc/stable/user/absolute_beginners.html) — Getting started
# - [10 Minutes to Pandas](https://pandas.pydata.org/docs/user_guide/10min.html) — Quick intro
