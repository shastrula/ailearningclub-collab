# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Scikit-learn Documentation](https://scikit-learn.org/stable/) — ML library reference
# - [StatQuest (YouTube)](https://www.youtube.com/c/joshstarmer) — Visual ML explanations
# - [An Introduction to Statistical Learning](https://www.statlearning.com/) — Free textbook (ISLR)
# - [Kaggle Competitions](https://www.kaggle.com/competitions) — Practice with real datasets
# - [Google ML Crash Course](https://developers.google.com/machine-learning/crash-course) — Free supervised learning course
