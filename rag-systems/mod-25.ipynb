# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [LangChain Documentation](https://python.langchain.com/) — RAG framework documentation
# - [LlamaIndex](https://www.llamaindex.ai/) — Data framework for LLM applications
# - [Pinecone Learning Center](https://www.pinecone.io/learn/) — Vector database concepts
# - [Chunking Strategies (Pinecone)](https://www.pinecone.io/learn/chunking-strategies/) — Text splitting best practices
# - [RAGAS](https://docs.ragas.io/) — RAG evaluation framework
