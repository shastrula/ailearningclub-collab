# %% [markdown]
# # Fundamentals of Vector Databases

# %% [markdown]
# ## Introduction to Vector Databases

# %% [markdown]
# Vector databases are specialized databases designed to handle high-dimensional vector data efficiently. Unlike traditional relational databases that store data in tables, vector databases store data as vectors, which are mathematical representations of data points in multi-dimensional space. This allows for advanced operations like similarity search, clustering, and dimensionality reduction, making them ideal for applications that require complex data analysis.
#
# ### Why Use Vector Databases?
#
# Traditional databases are optimized for structured data and simple queries like SQL. However, in modern applications, data is often unstructured and high-dimensional. For example, images, text, and user behavior data are typically represented as vectors. Vector databases are optimized for these types of data, allowing for efficient storage, retrieval, and analysis.
#
# ### How Vector Databases Work
#
# Vector databases use algorithms like Approximate Nearest Neighbor (ANN) to perform fast similarity searches. These algorithms trade a small amount of accuracy for significant speed gains, making them suitable for real-time applications.

# %% [markdown]
# ## Real-World Case Studies

# %% [markdown]
# ### Case Study 1: Recommendation Systems
#
# **Company:** Netflix
#
# **Application:** Personalized Recommendations
#
# **Description:** Netflix uses vector databases to store user interaction data as vectors. By leveraging similarity search algorithms, Netflix can quickly find similar users or items, enabling personalized recommendations that enhance user experience.
#
# ### Case Study 2: Natural Language Processing
#
# **Company:** Google
#
# **Application:** Semantic Search
#
# **Description:** Google uses vector databases to understand and process text data. By converting words and sentences into embeddings, Google can perform tasks like semantic search, where the goal is to find documents that are semantically similar to a query. This enhances the relevance of search results.

# %% [markdown]
# ## Hands-On Code Examples

# %% [markdown]
# ### Example 1: Calculating Cosine Similarity
#
#
#
# ### Example 2: Generating Embeddings

# %%
import numpy as np

# Example vectors
vector1 = np.array([1, 2, 3])
vector2 = np.array([4, 5, 6])

# Calculate cosine similarity
def cosine_similarity(vec1, vec2):
    """
    Compute the cosine similarity between two vectors.
    
    Parameters:
    vec1 (np.array): First vector
    vec2 (np.array): Second vector
    
    Returns:
    float: Cosine similarity score
    """
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)

# Compute similarity
similarity = cosine_similarity(vector1, vector2)
print(f'Cosine similarity: {similarity}')

# %%
from sentence_transformers import SentenceTransformer

# Load pre-trained model
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Example sentences
sentences = ['This is an example sentence.', 'Each sentence is converted into a vector.']

# Generate embeddings
embeddings = model.encode(sentences)
"""
Generate vector representations (embeddings) for each sentence.

Parameters:
sentences (list): List of sentences to encode

Returns:
np.array: Array of embeddings
"""
print(f'Embeddings: {embeddings}')

# %% [markdown]
# ## Key Concepts

# %% [markdown]
# | **Concept** | **Description** |
# |-------------|-----------------|
# | **Vector Database** | A database optimized for storing and querying high-dimensional vectors |
# | **Approximate Nearest Neighbor (ANN)** | Algorithm for fast similarity search that trades small accuracy for large speed gains |
# | **HNSW** | Hierarchical Navigable Small World — a graph-based ANN algorithm used by most vector DBs |
# | **Cosine Similarity** | Measures the angle between two vectors to determine semantic similarity |

# %% [markdown]
# ## Interactive Quizzes

# %% [markdown]
# ### Quiz 1: What is the primary purpose of a vector database?
# - [ ] To store relational data in tables
# - [✓] To handle high-dimensional vector data efficiently
# - [ ] To perform simple CRUD operations
# - [ ] To manage text documents
#
# ### Quiz 2: What do embeddings represent in natural language processing?
# - [ ] Raw text data
# - [✓] Vector representations of words or sentences that capture semantic meaning
# - [ ] Database tables
# - [ ] SQL queries
#
# ### Quiz 3: Why use a vector database instead of a regular database for RAG?
# - [ ] Lower cost
# - [✓] Faster similarity search on high-dimensional data
# - [ ] Better SQL support
# - [ ] Easier backups
