# %% [markdown]
# # Java Fundamentals - mod-1-intro
#
# **Course:** java-fundamentals
#
# Run the code cells below to practice. Code is loaded from GitHub using IPython magic.

# %%
# %load https://raw.githubusercontent.com/ailearningclub/ailearningclub-collab/main/code/java-fundamentals/mod-1-intro/part-1.py
