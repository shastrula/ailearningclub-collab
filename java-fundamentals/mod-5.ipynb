# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Oracle Java Tutorials](https://docs.oracle.com/javase/tutorial/) — Official tutorials
# - [W3Schools Java](https://www.w3schools.com/java/) — Beginner reference
# - [JDoodle](https://www.jdoodle.com/online-java-compiler/) — Online compiler
