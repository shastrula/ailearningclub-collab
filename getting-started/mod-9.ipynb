# %% [markdown]
# # Next Steps in Your AI Journey

# %% [markdown]
# ## What You've Learned

# %% [markdown]
# Congratulations on completing the foundational course! You've gained essential skills, including:
#
# - **Version Control with Git:** Understanding how to manage code changes and collaborate effectively.
# - **Python Fundamentals:** Grasping the basics of Python programming.
# - **Machine Learning Basics:** Building and training a machine learning model.
#
# Now, let's explore the next steps to elevate your AI journey.

# %% [markdown]
# ## In-depth Explanations and Real-World Case Studies

# %% [markdown]
# ### Advanced Python Skills
#
# **Why It Matters:** Python is the backbone of AI and machine learning. Advanced Python skills will enable you to write more efficient, readable, and maintainable code.
#
# **How to Achieve It:** Dive deeper into Python by learning about decorators, generators, context managers, and advanced data structures.
#
# **Case Study:** At Google, Python is used extensively for data processing and machine learning tasks. Advanced Python skills help engineers optimize their code for better performance and scalability.
#
# ### Core Machine Learning Concepts
#
# **Why It Matters:** A solid understanding of core ML concepts is crucial for building effective AI systems.
#
# **How to Achieve It:** Study algorithms like decision trees, ensemble methods, and support vector machines. Understand the mathematics behind these algorithms.
#
# **Case Study:** Netflix uses machine learning algorithms to recommend shows to users. By understanding core ML concepts, engineers at Netflix can improve their recommendation system's accuracy and user satisfaction.
#
# ### Deep Learning
#
# **Why It Matters:** Deep learning is at the forefront of AI, powering applications like image recognition, natural language processing, and more.
#
# **How to Achieve It:** Learn about neural networks, convolutional neural networks (CNNs), recurrent neural networks (RNNs), and transformers.
#
# **Case Study:** Facebook uses deep learning for facial recognition in photos. By mastering deep learning, you can build similar complex AI applications.
#
# ### Retrieval-Augmented Generation (RAG) Systems
#
# **Why It Matters:** RAG systems combine retrieval-based and generative models to provide more accurate and context-aware responses.
#
# **How to Achieve It:** Study how to build systems that can fetch relevant information from a database and generate coherent responses.
#
# **Case Study:** Amazon uses RAG systems to enhance their customer service chatbots, providing more accurate and helpful responses to customer queries.

# %% [markdown]
# ## Hands-On Code Examples

# %% [markdown]
# ### Advanced Python: Using Decorators
#
#
#
# ### Core Machine Learning: Decision Tree
#
#
#
# ### Deep Learning: Simple Neural Network with PyTorch

# %%
# Define a simple decorator
def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

@my_decorator
def say_hello():
    print("Hello!")

say_hello()
# Output:
# Something is happening before the function is called.
# Hello!
# Something is happening after the function is called.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_iris()
X, y = data.data, data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train model
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test)

# Evaluate model
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define a simple neural network
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(784, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

net = Net()

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01)

# Training loop (simplified)
for epoch in range(10):  # loop over the dataset multiple times
    optimizer.zero_grad()   # zero the parameter gradients
    outputs = net(inputs)   # forward pass
    loss = criterion(outputs, labels)   # compute loss
    loss.backward()    # backward pass
    optimizer.step()    # update parameters

# %% [markdown]
# ## Practice Projects

# %% [markdown]
# ### Build a Classifier for a Different Dataset
#
# Choose a dataset from [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php) and build a classifier. This will help you apply your machine learning skills to real-world data.
#
# ### Create a Prediction API with Flask
#
# Build a simple web application using Flask that allows users to input data and receive predictions from your machine learning model.
#
# ### Contribute to Open-Source ML Projects on GitHub
#
# Find open-source machine learning projects on GitHub and contribute by fixing bugs, adding features, or improving documentation.
#
# ### Build a Chatbot Using NLP Techniques
#
# Use natural language processing techniques to build a chatbot. You can start with simple rule-based systems and gradually move to more complex models like sequence-to-sequence models.
#
# > **💡 Tip:** The best way to learn is by doing. Start small, commit often, and gradually build more complex projects.

# %% [markdown]
# ## Interactive Quizzes

# %% [markdown]
# ### Quiz 1: What is the most important habit for AI developers?
# - [ ] Writing perfect code on the first try
# - [✓] Using Git to track changes and collaborate
# - [ ] Memorizing all algorithms
# - [ ] Working alone on projects
#
# ### Quiz 2: Which of the following is a core machine learning concept?
# - [ ] Writing perfect code on the first try
# - [✓] Understanding decision trees
# - [ ] Memorizing all algorithms
# - [ ] Working alone on projects
#
# ### Quiz 3: What is a Retrieval-Augmented Generation (RAG) system used for?
# - [ ] Writing perfect code on the first try
# - [ ] Memorizing all algorithms
# - [✓] Fetching relevant information and generating coherent responses
# - [ ] Working alone on projects
