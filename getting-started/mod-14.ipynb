# %% [markdown]
# # Resources & References

# %% [markdown]
# ## Recommended Resources

# %% [markdown]
# ** [VS Code](https://code.visualstudio.com/) — Recommended editor
#
# ** [VS Code Documentation](https://code.visualstudio.com/docs) — Official guide and tutorials
#
# ** [Git Documentation](https://git-scm.com/doc) — Official version control reference
#
# ** [GitHub Learning Lab](https://github.com/skills) — Interactive Git and GitHub skills
#
# ** [Python Official Documentation](https://docs.python.org/3/) — Language reference and standard library
#
# ** [Google Colab](https://colab.research.google.com/) — Free cloud notebooks for ML
#
# > **💡 Tip:** Bookmark these resources and revisit them as you progress through your learning journey. Many of these sites offer additional courses, documentation, and community support.
