# %% [markdown]
# # Kiro Spec Dev - mod-1
#
# **Course:** kiro-spec-dev
#
# Run the code cells below to practice. Code is loaded from GitHub using IPython magic.

# %%
# %load https://raw.githubusercontent.com/ailearningclub/ailearningclub-collab/main/code/kiro-spec-dev/mod-1/part-1.py
