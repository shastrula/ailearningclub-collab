# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Kiro Documentation](https://kiro.dev/docs) — Official Kiro docs
# - [Spec-Driven Development](https://swagger.io/resources/articles/adopting-an-api-first-approach/) — API-first approach
# - [AWS Documentation](https://docs.aws.amazon.com/) — AWS services reference
