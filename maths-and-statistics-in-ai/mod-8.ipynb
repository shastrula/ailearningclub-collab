# %% [markdown]
# # Maths And Statistics In Ai - mod-8
#
# **Course:** maths-and-statistics-in-ai
#
# Run the code cells below to practice. Code is loaded from GitHub using IPython magic.

# %%
# %load https://raw.githubusercontent.com/ailearningclub/ailearningclub-collab/main/code/maths-and-statistics-in-ai/mod-8/part-1.py
