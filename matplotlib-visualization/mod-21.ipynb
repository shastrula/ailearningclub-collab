# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Matplotlib Documentation](https://matplotlib.org/stable/) — Official docs
# - [Seaborn Documentation](https://seaborn.pydata.org/) — Statistical visualization
# - [Plotly Documentation](https://plotly.com/python/) — Interactive charts
# - [Python Graph Gallery](https://www.python-graph-gallery.com/) — Chart examples
