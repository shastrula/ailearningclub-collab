# %% [markdown]
# # Mlops - mod-23
#
# **Course:** mlops
#
# This notebook loads code from GitHub. Run the cells below.

# %%
import requests
from IPython.display import display, Markdown

base_url = f'https://raw.githubusercontent.com/shastrula/ailearningclub-collab/main/code/{course}/{module_id}'

# Load and execute all part files
for i in range(1, 10):  # Try up to 10 parts
    url = f'{base_url}/part-{i}.py'
    try:
        response = requests.get(url, timeout=5)
        if response.status_code == 200:
            print(f'\n=== Part {i} ===')
            exec(response.text)
        else:
            break
    except:
        break
