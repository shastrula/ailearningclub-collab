# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [MLflow Documentation](https://mlflow.org/docs/latest/index.html) — Experiment tracking & model registry
# - [DVC (Data Version Control)](https://dvc.org/doc) — Version control for ML projects
# - [Made With ML](https://madewithml.com/) — MLOps course with best practices
# - [Evidently AI](https://www.evidentlyai.com/) — ML monitoring and observability
# - [Google MLOps Guide](https://cloud.google.com/architecture/mlops-continuous-delivery-and-automation-pipelines-in-machine-learning) — MLOps maturity levels
