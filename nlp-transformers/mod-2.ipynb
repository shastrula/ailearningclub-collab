# %% [markdown]
# # Overview of Transformers

# %% [markdown]
# ## Understanding Transformers

# %% [markdown]
# ### What are Transformers?
#
# Transformers are a type of deep learning model introduced in the paper ["Attention is All You Need"](https://arxiv.org/abs/1706.03762) by Vaswani et al. in 2017. They leverage self-attention mechanisms to process input data, allowing them to handle sequences more efficiently than traditional models like Recurrent Neural Networks (RNNs).
#
# ### Why Transformers?
#
# **Efficiency:** Unlike RNNs, which process input sequences step-by-step, Transformers can process entire sequences simultaneously. This parallel processing capability makes them significantly faster and more efficient.
#
# **Scalability:** Transformers can scale to very long sequences, making them suitable for a wide range of NLP tasks, from language translation to text summarization.
#
# ### How do Transformers Work?
#
# Transformers consist of an encoder-decoder structure. The encoder processes the input sequence and generates a representation, while the decoder takes this representation and generates the output sequence.
#
# **Self-Attention Mechanism:** The core of the Transformer is the self-attention mechanism, which allows the model to weigh the importance of different words in a sentence. This helps the model understand the context and relationships between words.
#
# ### In-Depth Explanation: Self-Attention Mechanism
#
# The self-attention mechanism computes a weighted sum of the input embeddings, where the weights are determined by the similarity between the words. This is achieved through three main steps:
#
# 1. **Query, Key, and Value Vectors:** Each input embedding is transformed into three vectors—Query (Q), Key (K), and Value (V).
# 2. **Attention Scores:** The attention scores are calculated by taking the dot product of the Query vector with all Key vectors.
# 3. **Softmax and Weighted Sum:** The attention scores are passed through a softmax function to obtain probabilities, which are then used to compute a weighted sum of the Value vectors.
#
# This mechanism allows the model to focus on different parts of the input sequence when generating each part of the output sequence.

# %% [markdown]
# ## Hands-On Code Example

# %% [markdown]
# Let's look at a simple example using the Hugging Face Transformers library to encode a sample text with BERT.
#
#
#
# **Explanation:**
# - **Tokenizer:** Converts the input text into token IDs that the model can understand.
# - **Model:** Processes the token IDs and generates a representation of the input text.
# - **Last Hidden State:** The final representation of the input text, capturing contextual information about each word.

# %%
from transformers import BertTokenizer, BertModel
import torch

# Initialize BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Encode a sample text
inputs = tokenizer('Hello, how are you?', return_tensors='pt')
outputs = model(**inputs)

# Print the last hidden state
print(outputs.last_hidden_state)

# %% [markdown]
# ## Real-World Case Studies

# %% [markdown]
# ### Case Study 1: Google's BERT in Search
#
# Google uses BERT to improve the understanding of search queries. By leveraging BERT's deep understanding of language, Google can provide more accurate and relevant search results. For example, when a user types "2021 weather in NYC," BERT can understand the context and provide results for the weather in New York City for the year 2021, rather than misinterpreting the query.
#
# ### Case Study 2: Amazon's Alexa
#
# Amazon's Alexa uses Transformers to understand and respond to user queries. The self-attention mechanism helps Alexa grasp the context of conversations, making interactions more natural and effective. For instance, if a user says, "I like the new Batman movie," Alexa can understand the context and provide relevant information or recommendations based on the user's preference.

# %% [markdown]
# ## Fine-Tuning Transformers

# %% [markdown]
# ### What is Fine-Tuning?
#
# Fine-tuning involves taking a pre-trained model and adapting it to a specific task. This is particularly useful when you have a limited amount of data for the target task. Hugging Face's Transformers library makes fine-tuning straightforward.
#
# ### Hands-On Example: Fine-Tuning BERT for Sentiment Analysis
#
#
#
# **Explanation:**
# - **Dataset:** The IMDB dataset is used for sentiment analysis.
# - **Model Initialization:** BERT is initialized for sequence classification.
# - **Training Arguments:** Define hyperparameters for training.
# - **Trainer:** Manages the training process.
# - **Training:** Fine-tunes the model on the dataset.

# %%
from transformers import BertForSequenceClassification, Trainer, TrainingArguments
from datasets import load_dataset

# Load a dataset
dataset = load_dataset('imdb')

# Initialize the model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased')

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy='epoch',
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset['train'],
    eval_dataset=dataset['test']
)

# Train the model
trainer.train()

# %% [markdown]
# ## Interactive Quizzes

# %% [markdown]
# ### Quiz 1: What is the primary advantage of using Transformers over RNNs?
# - [ ] They can process data sequentially
# - [✓] They can process entire sequences simultaneously
# - [ ] They are simpler to implement
# - [ ] They require less computational power
#
# ### Quiz 2: What is the purpose of fine-tuning a pre-trained model?
# - [ ] To train a model from scratch
# - [✓] To adapt a pre-trained model to a specific task
# - [ ] To evaluate the performance of the model
# - [ ] To reduce the size of the model
#
# ### Quiz 3: Which mechanism is at the core of the Transformer architecture?
# - [ ] Recurrent connections
# - [✓] Self-attention mechanism
# - [ ] Convolutional layers
# - [ ] Fully connected layers
