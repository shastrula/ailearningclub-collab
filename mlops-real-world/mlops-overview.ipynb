# %% [markdown]
# # Mlops Real World - mlops-overview
#
# **Course:** mlops-real-world
#
# Run the code cells below to practice. Code is loaded from GitHub using IPython magic.

# %%
# %load https://raw.githubusercontent.com/ailearningclub/ailearningclub-collab/main/code/mlops-real-world/mlops-overview/part-1.py
