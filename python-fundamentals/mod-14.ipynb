# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Python Official Documentation](https://docs.python.org/3/) — Complete language reference
# - [Real Python](https://realpython.com/) — Practical Python tutorials
# - [Automate the Boring Stuff](https://automatetheboringstuff.com/) — Free Python book for beginners
# - [PEP 8 Style Guide](https://peps.python.org/pep-0008/) — Python coding conventions
# - [Python Tutor](https://pythontutor.com/) — Visualize code execution step by step
#
#
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What is the main concept introduced in this module?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q14_0" value="0">
#       <span>Option A</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q14_1" value="1">
#       <span>Option B</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q14_2" value="2">
#       <span>Option C</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q14_3" value="3">
#       <span>Option D</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
