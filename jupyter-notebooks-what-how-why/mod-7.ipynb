# %% [markdown]
# # Jupyter Notebooks What How Why - mod-7
#
# **Course:** jupyter-notebooks-what-how-why
#
# Run the code cells below to practice. Code is loaded from GitHub using IPython magic.

# %%
# %load https://raw.githubusercontent.com/ailearningclub/ailearningclub-collab/main/code/jupyter-notebooks-what-how-why/mod-7/part-1.py
