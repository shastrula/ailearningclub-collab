# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Jupyter Documentation](https://jupyter.org/documentation) — Official docs
# - [JupyterLab](https://jupyterlab.readthedocs.io/) — Next-gen interface
# - [Google Colab](https://colab.research.google.com/) — Free hosted notebooks
# - [nbviewer](https://nbviewer.org/) — Share notebooks online
