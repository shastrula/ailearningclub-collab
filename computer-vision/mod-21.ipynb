# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [PyTorch Vision](https://pytorch.org/vision/stable/) — Torchvision models and transforms
# - [OpenCV Documentation](https://docs.opencv.org/) — Computer vision library
# - [CS231n (Stanford)](https://cs231n.stanford.edu/) — Convolutional Neural Networks course
# - [Roboflow](https://roboflow.com/) — Computer vision dataset tools
# - [Papers With Code - CV](https://paperswithcode.com/area/computer-vision) — Latest CV research
