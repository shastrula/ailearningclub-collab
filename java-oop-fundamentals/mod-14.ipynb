# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Oracle OOP Concepts](https://docs.oracle.com/javase/tutorial/java/concepts/) — Official OOP guide
# - [Head First Java (book)](https://www.oreilly.com/library/view/head-first-java/9781492091646/) — Visual learning
# - [Refactoring Guru](https://refactoring.guru/design-patterns/java) — Design patterns in Java
