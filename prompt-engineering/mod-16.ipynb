# %% [markdown]
# # Practical Applications of Advanced Prompting

# %% [markdown]
# ## Zero-shot and Few-shot Prompting

# %% [markdown]
# Zero-shot prompting involves providing a model with a task it has never seen before, without any examples. Few-shot prompting provides a few examples to guide the model. These techniques are essential for generalizing AI models to new tasks with minimal data.
#
# ```python title="example1.py"
# from transformers import pipeline
#
# # Zero-shot classification
# classifier = pipeline("zero-shot-classification")
#
# # Example input
# sequence_to_classify = "The quick brown fox jumps over the lazy dog"
# candidate_labels = ['animal','speed', 'nature']
#
# # Perform zero-shot classification
# result = classifier(sequence_to_classify, candidate_labels)
# print(result)
# ```
#
# > **Try it in Google Colab:** [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shastrula/ailearningclub-courses/blob/main/prompt-engineering/mod-16.ipynb)
#
#
# ```
# {'sequence': 'The quick brown fox jumps over the lazy dog', 'labels': ['animal','speed', 'nature'],'scores': [0.784, 0.123, 0.093]}
# ```

# %% [markdown]
# ## Chain-of-Thought (CoT) and ReAct Prompting

# %% [markdown]
# Chain-of-Thought prompting encourages models to provide intermediate reasoning steps before arriving at a final answer, enhancing the model's ability to solve complex problems. ReAct prompting combines reasoning and action, allowing models to perform tasks that require external information or actions.
#
# ```python title="example2.py"
# from transformers import pipeline
#
# # Text generation pipeline
# generator = pipeline("text-generation")
#
# # Example input using CoT
# prompt = "What is the capital of France? Let's think step by step: France is a country in Europe. The capital of France is Paris."
#
# # Generate text
# result = generator(prompt, max_length=50)
# print(result[0]['generated_text'])
# ```
#
# > **💡 Tip:** When using Chain-of-Thought prompting, ensure that the intermediate steps are logically coherent and relevant to the final answer to improve the model's performance.
#
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ Which technique involves providing a model with a task it has never seen before, without any examples?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386960704" value="0">
#       <span>Few-shot prompting</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386960704" value="1">
#       <span>Chain-of-Thought prompting</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386960704" value="2">
#       <span>Zero-shot prompting</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386960704" value="3">
#       <span>ReAct prompting</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
#
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ What does CoT prompting encourage models to do before arriving at a final answer?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386962944" value="0">
#       <span>Provide intermediate reasoning steps</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386962944" value="1">
#       <span>Perform external actions</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386962944" value="2">
#       <span>Generate random text</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4386962944" value="3">
#       <span>Classify input data</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>

# %% [markdown]
# ## Key Concepts

# %% [markdown]
# ## Check Your Understanding

# %% [markdown]
# <div class="quiz" data-correct="3">
#   <p class="font-semibold mb-3">❓ What are the theoretical foundations of Practical?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8474376849" value="0">
#       <span>Empirical</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8474376849" value="1">
#       <span>Statistical</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8474376849" value="2">
#       <span>Probabilistic</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q8474376849" value="3">
#       <span>All of the above</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
# <div class="quiz" data-correct="0">
#   <p class="font-semibold mb-3">❓ How does Practical scale to large datasets?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4084755338" value="0">
#       <span>Linearly</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4084755338" value="1">
#       <span>Quadratically</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4084755338" value="2">
#       <span>Logarithmically</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q4084755338" value="3">
#       <span>Exponentially</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
# <div class="quiz" data-correct="2">
#   <p class="font-semibold mb-3">❓ What are common failure modes of Practical?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q6754594016" value="0">
#       <span>Overfitting</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q6754594016" value="1">
#       <span>Underfitting</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q6754594016" value="2">
#       <span>Both</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q6754594016" value="3">
#       <span>Neither</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
# <div class="quiz" data-correct="3">
#   <p class="font-semibold mb-3">❓ How can you optimize Practical for production?</p>
#   <div class="space-y-2">
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q847368308" value="0">
#       <span>Quantization</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q847368308" value="1">
#       <span>Pruning</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q847368308" value="2">
#       <span>Distillation</span>
#     </label>
#     <label class="flex items-center gap-2 cursor-pointer">
#       <input type="radio" name="q847368308" value="3">
#       <span>All of the above</span>
#     </label>
#   </div>
#   <button class="quiz-btn mt-3 px-4 py-2 bg-blue-600 text-white rounded text-sm font-medium hover:bg-blue-700">Check Answer</button>
#   <p class="quiz-result text-sm mt-2 hidden"></p>
# </div>
