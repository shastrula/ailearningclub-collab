# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [OpenAI Prompt Engineering Guide](https://platform.openai.com/docs/guides/prompt-engineering) — Official best practices
# - [Anthropic Prompt Engineering](https://docs.anthropic.com/en/docs/build-with-claude/prompt-engineering) — Claude prompting guide
# - [Learn Prompting](https://learnprompting.org/) — Free prompt engineering course
# - [Prompt Engineering Guide (DAIR.AI)](https://www.promptingguide.ai/) — Comprehensive techniques
# - [Chain-of-Thought Prompting (paper)](https://arxiv.org/abs/2201.11903) — Research on reasoning prompts
