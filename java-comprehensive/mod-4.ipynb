# %% [markdown]
# # Resources & References

# %% [markdown]
# ## 📚 Resources & References

# %% [markdown]
# - [Oracle Java Tutorials](https://docs.oracle.com/javase/tutorial/) — Official tutorials
# - [Baeldung](https://www.baeldung.com/) — Practical Java guides
# - [JDoodle](https://www.jdoodle.com/online-java-compiler/) — Online Java compiler
